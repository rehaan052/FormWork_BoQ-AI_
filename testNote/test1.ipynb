# %%
import pandas as pd

df=pd.read_csv("/Users/rehaanraza/Desktop/ProjectSQL/FormWork_BoQ-AI_/data/processed/ml_training_data.csv")


print(df.columns)
# Out:
# Index(['project_type', 'floors', 'element_type', 'formwork_type', 'area_sqm',
#        'quantity', 'cycle_time_days', 'total_units', 'reuse_limit',
#        'required_new_units'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# project_type           object
# floors                  int64
# element_type           object
# formwork_type          object
# area_sqm              float64
# quantity                int64
# cycle_time_days         int64
# total_units             int64
# reuse_limit             int64
# required_new_units    float64
# dtype: object
