# %%
import pandas as pd

df=pd.read_csv("/Users/rehaanraza/Desktop/ProjectSQL/FormWork_BoQ-AI_/data/boq_traditional.csv")


print(df.columns)
# Out:
# Index(['project_id', 'floor_no', 'element_type', 'planned_start_day',
#        'cycle_time_days', 'actual_start_day', 'formwork_type', 'area_sqm',
#        'quantity', 'cost_per_sqm', 'total_cost'],
#       dtype='object')
